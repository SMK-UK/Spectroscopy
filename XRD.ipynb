# %%
import spec_funcs as sf
import QMPlotter as qmp
import numpy as np

# %%
path = r"C:\Users\sk88\Desktop\Sean_Keenan\PowDLL_XY_XRD_Monday, May 22, 2023.csv"
data = sf.data_extract([path])

# %%
data_plot = qmp.plotter(data[0][0][0], np.log(data[0][0][1]))
data_plot.x_lbl = "2${\Theta}$"
data_plot.y_lbl = 'Intensity (AU)'
data_plot.display()
# Out:
# c:\Users\sk88\Documents\Python\Spectroscopy\QMPlotter.py:58: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "x" (-> marker='x'). The keyword argument will take precedence.
#   self.ax.plot(x, y, 'x', color=self.colour, linestyle=self.linestyle,
